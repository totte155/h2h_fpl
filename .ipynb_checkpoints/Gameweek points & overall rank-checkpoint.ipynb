# %% [markdown]
# # Manager performance

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style
import seaborn as sns

#GET GAMEWEEK DATA FUNCTION - TO BE COMPLETED 
def fpl_api_query(player_id):
    players = {
        'Totte': "4512595",
        'Pappa': "1989627",
        'Frej': "1987616",
        'Phil': "4279435",
        'Tommi': "3013919",
        'Pat': "3414317",
    }
    for player, id in players.items():
        url = f"https://fantasy.premierleague.com/api/entry/{id}/history/"
        #API request
        response = requests.get(url).json()
        relevant_API_data = response["current"]

# %%
teamid = 4512595

url = f'https://fantasy.premierleague.com/api/entry/{teamid}/history/'

#API request
response = requests.get(url).json()
#Accesses the gameweek section of API
relevant_API_data = response["current"]


df = pd.DataFrame(relevant_API_data)

df.head()
# Out:
#    event  points  total_points     rank  rank_sort  overall_rank  \
# 0      1      75            75   704705     770990        704705
# 1      2      71           146  4445939    4494830       1451656
# 2      3      71           217  3748271    3785687       1754034
# 3      4      56           273  3536260    3597797       1509314
# 4      5      59           332  4728959    4796150       1815811
#
#    percentile_rank  bank  value  event_transfers  event_transfers_cost  \
# 0               10     0   1000                0                     0
# 1               50     0   1000                0                     0
# 2               40     8    998                1                     0
# 3               35     1   1001                0                     0
# 4               50     1   1003                0                     0
#
#    points_on_bench
# 0                2
# 1                3
# 2                0
# 3                1
# 4                1

# %%
# Set the Seaborn dark theme with subtle gridlines
sns.set_theme(style="darkgrid", rc={
    'axes.facecolor': '#1E1E1E',       # Dark background for axes
    'figure.facecolor': '#1E1E1E',     # Dark background for the figure
    'axes.edgecolor': '#333333',       # Less prominent edges for axes
    'text.color': 'white',             # White text for readability
    'axes.labelcolor': 'white',        # White axis labels
    'xtick.color': '#888888',          # Less prominent x-axis ticks
    'ytick.color': '#888888',          # Less prominent y-axis ticks
    'grid.color': '#333333',           # Darker gridlines for subtle contrast
    'grid.linewidth': 0.5              # Thinner gridlines
})

# %%
# Set up the figure with gridspec
fig = plt.figure(figsize=(14, 10))
gs = fig.add_gridspec(2, 2, height_ratios=[1, 1], hspace=0.4)

# Points per gameweek 
ax1 = fig.add_subplot(gs[0, :])
sns.lineplot(x='event',y='points',data=df,color="orange",marker ='o',ax=ax1)
ax1.set_title("Gameweek points")
ax1.set_xlabel("Gameweek")
ax1.set_ylabel("Points")

# Rank by gameweek 
ax2 = fig.add_subplot(gs[1,0])
sns.lineplot(x='event',y='overall_rank',data=df,color="orange", marker ='o',ax=ax2)
ax2.set_title("Overall rank (million)")
ax2.set_xlabel("Gameweek")
ax2.set_ylabel("Overal rank")
ax2.invert_yaxis()

#Squad vale 
ax3 = fig.add_subplot(gs[1,1])
sns.lineplot(x='event',y='value',data=df,color="orange",marker ='o',ax=ax3)
ax3.set_title("Sqaud value")
ax3.set_xlabel("Gameweek")
ax3.set_ylabel("Value (£ million)")
# Out:
# Text(0, 0.5, 'Value (£ million)')

# %% [markdown]
# # Player performance

# %% [markdown]
# Method:
# 1) Get list of managers players - function 1
# 2) Get element ID for each player via bootstrap (https://www.game-change.co.uk/2023/02/10/a-complete-guide-to-the-fantasy-premier-league-fpl-api/) - function 2
# 3) Get player performance for each player
# 4) Breakdown points by midfielder
